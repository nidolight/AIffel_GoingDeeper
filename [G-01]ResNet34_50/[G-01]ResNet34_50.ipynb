# %% [markdown]
# -
# github 출력 안보이는 경우 [nbviewer](https://nbviewer.org/github/nidolight/AIffel_GoingDeeper/blob/main/%5BG-01%5DResNet34_50/%5BG-01%5DResNet34_50.ipynb)에서 확인

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) ResNet 기본 블록 구성하기
# ![image.png](attachment:image.png)
#
# 2015년 ResNet을 소개한 [논문](https://arxiv.org/pdf/1512.03385.pdf)에서 ResNet-18, 34, 50, 101, 152의 다섯 가지 네트워크를 소개합니다. 이 중 ResNet-34와 50을 구현해 보겠습니다. <br>각 네트워크를 하나씩 구현하는 방법도 있지만 매우 수고스럽고 변경사항이 생기면 모두 고쳐줘야 하는 불편함이 생기게 됩니다. <br>따라서 ResNet의 기본 구조인 Residual 블록을 먼저 구현하겠습니다.
#
# ![image-2.png](attachment:image-2.png)

# %%
# function for building Residual Block
def build_Residual_block(x, filters=64, kernel_size=3, i=0, j=0, is_50=False):
    y = layers.Conv2D(filters, kernel_size=(1 if is_50 else kernel_size),
                      padding='same',
                      strides=(1 if i==0 and j==0 else 2 if j==0 else 1))(x)
    y = layers.BatchNormalization()(y)
    y = layers.Activation('relu')(y)

    y = layers.Conv2D(filters, kernel_size, padding='same')(y)
    y = layers.BatchNormalization()(y)
    
    if is_50:
        y = layers.Activation('relu')(y)
        y = layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          padding='same')(y)
        y = layers.BatchNormalization()(y)
        
        if j==0:
            x = layers.Conv2D(filters=filters*4, 
                              kernel_size=1, 
                              padding='same',
                              strides=(1 if i==0 and j==0 else 2))(x)
            x = layers.BatchNormalization()(x)
    else:
        if i>0 and j==0:
            x = layers.Conv2D(filters, kernel_size=1, padding='same',
                              strides=2)(x)
            x = layers.BatchNormalization()(x)
 
    y = layers.Add()([x,y])
    y = layers.Activation('relu')(y)
        
    return y

# %%
ResNet_input_layer = keras.layers.Input(shape=(32,32,64))   # 입력 레이어 생성

ResNet34_block_output = build_Residual_block(ResNet_input_layer,is_50=False)    # Residual 블록 생성
ResNet50_block_output = build_Residual_block(ResNet_input_layer,is_50=True)

# %%
# ResNet50 블록 1개짜리 model 생성
block34 = keras.Model(inputs=ResNet_input_layer, outputs=ResNet34_block_output)  
block34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 64)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   36928       ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 64)   36928       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 64)   0           ['input_1[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 64)   0           ['add[0][0]']
#
# ==================================================================================================
# Total params: 74,368
# Trainable params: 74,112
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
plot_model(block34, to_file='residual34_block.png', show_shapes=True, show_layer_names=True)

# %%
# ResNet50 블록 1개짜리 model 생성
block50 = keras.Model(inputs=ResNet_input_layer, outputs=ResNet50_block_output)  
block50.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 64)  0           []
#                                 ]
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   4160        ['input_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  16640       ['input_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  16640       ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 256)  0           ['add_1[0][0]']
#
# ==================================================================================================
# Total params: 76,928
# Trainable params: 75,648
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
plot_model(block50, to_file='residual50_block.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## 2) ResNet-34, ResNet-50 Complete Model
# 블록을 만드는 함수를 사용해서 직접 전체 모델을 만들어 봅시다. <br>
# ResNet-34와 ResNet-50의 차이에 따라 달라지는 구성(configuration)을 함수에 전달해서 같은 생성 함수 `build_resnet()`를 통해서 ResNet의 여러 가지 버전들을 모두 만들어 낼 수 있습니다.

# %%
def build_resnet(input_shape=(32, 32, 3),
                 num_blocks_list=[3, 4, 6, 3],
                 channel_list=[64,128,256,512],
                 num_classes = 10,
                 is_50=False):
    
    assert len(num_blocks_list) == len(channel_list) # 모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    
    input_layer = keras.layers.Input(shape=input_shape)    # input layer를 만들어둡니다.
    
    output = keras.layers.Conv2D(kernel_size=7,
                                 strides=2,
                                 filters=64,
                                 padding="same")(input_layer)
    output = keras.layers.BatchNormalization()(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size=2,
                                       strides=2,
                                       padding="same")(output)
    
    for i in range(len(num_blocks_list)):
        for j in range(num_blocks_list[i]):
            output = build_Residual_block(output,filters=channel_list[i],i=i,j=j,is_50=is_50)

    output = keras.layers.GlobalAveragePooling2D()(output)
    output = keras.layers.Dense(num_classes, activation='sigmoid')(output)#sigmoid사용
    
    
    model = keras.Model(
            inputs=input_layer, 
            outputs=output,
            name=('resnet50' if is_50 else 'resnet34')
    )

    return model

# %% [markdown]
# ### resnet34

# %%
resnet_34 = build_resnet(input_shape=(32,32,3), is_50=False)
resnet_34.summary()
# Out:
# Model: "resnet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   9472        ['input_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_6[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['activation_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 64)     36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_7 (Activation)      (None, 8, 8, 64)     0           ['add_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 64)    256         ['conv2d_10[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 8, 8, 64)     0           ['activation_7[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 64)     0           ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 64)    256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 64)    256         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 64)     0           ['activation_9[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_11 (Activation)     (None, 8, 8, 64)     0           ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 4, 4, 128)    73856       ['activation_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 4, 4, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 4, 4, 128)    8320        ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_15[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['add_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 4, 4, 128)   512         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 4, 4, 128)   512         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['activation_13[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  activation_15 (Activation)     (None, 4, 4, 128)    0           ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 4, 4, 128)   512         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 4, 4, 128)   512         ['conv2d_19[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 4, 4, 128)    0           ['activation_15[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  activation_17 (Activation)     (None, 4, 4, 128)    0           ['add_7[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 128)   512         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 128)   512         ['conv2d_21[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 4, 4, 128)    0           ['activation_17[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  activation_19 (Activation)     (None, 4, 4, 128)    0           ['add_8[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 2, 2, 256)    295168      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 2, 2, 256)    33024       ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_20[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_24[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_21 (Activation)     (None, 2, 2, 256)    0           ['add_9[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_21[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['activation_21[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['add_10[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_23[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['activation_23[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['add_11[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['activation_25[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_27 (Activation)     (None, 2, 2, 256)    0           ['add_12[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 2, 2, 256)    0           ['activation_27[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_29 (Activation)     (None, 2, 2, 256)    0           ['add_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_29[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 2, 2, 256)    0           ['activation_29[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_31 (Activation)     (None, 2, 2, 256)    0           ['add_14[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 1, 1, 512)    1180160     ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 1, 1, 512)    131584      ['activation_31[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_32[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_37[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_33 (Activation)     (None, 1, 1, 512)    0           ['add_15[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_33[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_39[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 1, 1, 512)    0           ['activation_33[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  activation_35 (Activation)     (None, 1, 1, 512)    0           ['add_16[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_35[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_41[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 1, 1, 512)    0           ['activation_35[0][0]',
#                                                                   'batch_normalization_41[0][0]']
#
#  activation_37 (Activation)     (None, 1, 1, 512)    0           ['add_17[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_37[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           5130        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,315,338
# Trainable params: 21,298,314
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %% [markdown]
# ### resnet50

# %%
resnet_50 = build_resnet(input_shape=(32,32,3), is_50=True)
resnet_50.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 64)   9472        ['input_3[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_42[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_38[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 64)     4160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 256)    16640       ['max_pooling2d_1[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_40[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_45[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_46[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  activation_41 (Activation)     (None, 8, 8, 256)    0           ['add_18[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_41[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 64)    256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 8, 8, 256)    0           ['activation_41[0][0]',
#                                                                   'batch_normalization_49[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 256)    0           ['add_19[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_44[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 8, 8, 64)    256         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_46[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_52[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 8, 8, 256)    0           ['activation_44[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_47 (Activation)     (None, 8, 8, 256)    0           ['add_20[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 4, 4, 128)    32896       ['activation_47[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 4, 4, 128)   512         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 4, 4, 128)   512         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 4, 4, 512)    131584      ['activation_47[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_49[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_55[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_56[0][0]',
#                                                                   'batch_normalization_55[0][0]']
#
#  activation_50 (Activation)     (None, 4, 4, 512)    0           ['add_21[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 4, 4, 128)    65664       ['activation_50[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 4, 4, 128)   512         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_51[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 4, 4, 128)   512         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_52[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 4, 4, 512)    0           ['activation_50[0][0]',
#                                                                   'batch_normalization_59[0][0]']
#
#  activation_53 (Activation)     (None, 4, 4, 512)    0           ['add_22[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 128)    65664       ['activation_53[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 4, 4, 128)   512         ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 4, 4, 128)   512         ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_62[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 4, 4, 512)    0           ['activation_53[0][0]',
#                                                                   'batch_normalization_62[0][0]']
#
#  activation_56 (Activation)     (None, 4, 4, 512)    0           ['add_23[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 4, 4, 128)    65664       ['activation_56[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 4, 4, 128)   512         ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 4, 4, 128)   512         ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 4, 4, 512)    0           ['activation_56[0][0]',
#                                                                   'batch_normalization_65[0][0]']
#
#  activation_59 (Activation)     (None, 4, 4, 512)    0           ['add_24[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 2, 2, 256)    131328      ['activation_59[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_66[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_60[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 2, 2, 1024)   525312      ['activation_59[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_61[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_69[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_68[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 2, 2, 1024)   0           ['batch_normalization_69[0][0]',
#                                                                   'batch_normalization_68[0][0]']
#
#  activation_62 (Activation)     (None, 2, 2, 1024)   0           ['add_25[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_62[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_63[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_64[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_72[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 2, 2, 1024)   0           ['activation_62[0][0]',
#                                                                   'batch_normalization_72[0][0]']
#
#  activation_65 (Activation)     (None, 2, 2, 1024)   0           ['add_26[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_65[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_66[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_67[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_75[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 2, 2, 1024)   0           ['activation_65[0][0]',
#                                                                   'batch_normalization_75[0][0]']
#
#  activation_68 (Activation)     (None, 2, 2, 1024)   0           ['add_27[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_68[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_76[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_69[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_70[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_78[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 2, 2, 1024)   0           ['activation_68[0][0]',
#                                                                   'batch_normalization_78[0][0]']
#
#  activation_71 (Activation)     (None, 2, 2, 1024)   0           ['add_28[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_71[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_79[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_79[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_72[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_73[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_81[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 2, 2, 1024)   0           ['activation_71[0][0]',
#                                                                   'batch_normalization_81[0][0]']
#
#  activation_74 (Activation)     (None, 2, 2, 1024)   0           ['add_29[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 2, 2, 256)    262400      ['activation_74[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_82[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_75[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_83[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 2, 2, 1024)   263168      ['activation_76[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 2, 2, 1024)  4096        ['conv2d_84[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 2, 2, 1024)   0           ['activation_74[0][0]',
#                                                                   'batch_normalization_84[0][0]']
#
#  activation_77 (Activation)     (None, 2, 2, 1024)   0           ['add_30[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 1, 1, 512)    524800      ['activation_77[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_85[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_78[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 1, 1, 2048)   2099200     ['activation_77[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_79[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_87[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_88[0][0]',
#                                                                   'batch_normalization_87[0][0]']
#
#  activation_80 (Activation)     (None, 1, 1, 2048)   0           ['add_31[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 1, 1, 512)    1049088     ['activation_80[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_81[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_82[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_91[0][0]']
#  ormalization)
#
#  add_32 (Add)                   (None, 1, 1, 2048)   0           ['activation_80[0][0]',
#                                                                   'batch_normalization_91[0][0]']
#
#  activation_83 (Activation)     (None, 1, 1, 2048)   0           ['add_32[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 1, 1, 512)    1049088     ['activation_83[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_92[0][0]']
#  ormalization)
#
#  activation_84 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_84[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_85[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_94[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 1, 1, 2048)   0           ['activation_83[0][0]',
#                                                                   'batch_normalization_94[0][0]']
#
#  activation_86 (Activation)     (None, 1, 1, 2048)   0           ['add_33[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['activation_86[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           20490       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3) 일반 네트워크(plain network) 만들기
# PLain network도 resnet을 구현한 것과 마찬가지로 블록 단위를 만들어 주어 구현합니다.<br>
# Plain Block은 앞서 구현한 Residual Block에서 shortcut을 add해주는 부분(skip connection)만 빼면 쉽게 만들 수 있습니다.

# %%
# function for building Residual Block
def build_Plain_block(x, filters=64, kernel_size=3, i=0, j=0, is_50=False):
    y = layers.Conv2D(filters, kernel_size=(1 if is_50 else kernel_size),
                      padding='same',
                      strides=(1 if i==0 and j==0 else 2 if j==0 else 1))(x)
    y = layers.BatchNormalization()(y)
    y = layers.Activation('relu')(y)

    y = layers.Conv2D(filters, kernel_size, padding='same')(y)
    y = layers.BatchNormalization()(y)
    
    if is_50:
        y = layers.Activation('relu')(y)
        y = layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          padding='same')(y)
        y = layers.BatchNormalization()(y)
        
    #     if j==0:
    #         x = layers.Conv2D(filters=filters*4, 
    #                           kernel_size=1, 
    #                           padding='same',
    #                           strides=(1 if i==0 and j==0 else 2))(x)
    #         x = layers.BatchNormalization()(x)
    # else:
    #     if i>0 and j==0:
    #         x = layers.Conv2D(filters, kernel_size=1, padding='same',
    #                           strides=2)(x)
    #         x = layers.BatchNormalization()(x)
 
    # y = layers.Add()([x,y])
    y = layers.Activation('relu')(y)
        
    return y

# %% [markdown]
# Plain network도 ResNet과 마찬가지로 34, 50레이어를 각각 만들어줍니다.

# %%
def build_plainnet(input_shape=(32, 32, 3),
                 num_blocks_list=[3, 4, 6, 3],
                 channel_list=[64,128,256,512],
                 num_classes=10,
                 is_50=False):
    
    assert len(num_blocks_list) == len(channel_list)
    
    input_layer = keras.layers.Input(shape=input_shape) 
    
    output = keras.layers.Conv2D(kernel_size=7,
                                 strides=2,
                                 filters=64,
                                 padding="same")(input_layer)
    output = keras.layers.BatchNormalization()(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size=2,
                                       strides=2,
                                       padding="same")(output)
    
    for i in range(len(num_blocks_list)):
        for j in range(num_blocks_list[i]):
            #이 부분만 수정 Residual_block -> Plain_block
            output = build_Plain_block(output,filters=channel_list[i],i=i,j=j,is_50=is_50)

    output = keras.layers.GlobalAveragePooling2D()(output)
    output = keras.layers.Dense(num_classes, activation='sigmoid')(output)
    
    
    model = keras.Model(
            inputs=input_layer, 
            outputs=output,
            name=('plainnet50' if is_50 else 'plainnet34')
    )

    return model

# %% [markdown]
# ### plainnet34

# %%
plain_34 = build_plainnet(input_shape=(224,224,3), is_50=False)
plain_34.summary()
# Out:
# Model: "plainnet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_95 (Conv2D)          (None, 112, 112, 64)      9472
#
#  batch_normalization_95 (Bat  (None, 112, 112, 64)     256
#  chNormalization)
#
#  activation_87 (Activation)  (None, 112, 112, 64)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_96 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_96 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_88 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_97 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_97 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_89 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_98 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_98 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_90 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_99 (Conv2D)          (None, 56, 56, 64)        36928
#
#  batch_normalization_99 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  activation_91 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_100 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_100 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_92 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_101 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_101 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 56, 56, 64)        0
#
#  conv2d_102 (Conv2D)         (None, 28, 28, 128)       73856
#
#  batch_normalization_102 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_103 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_103 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_104 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_104 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_105 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_105 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_106 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_106 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_107 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_107 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_99 (Activation)  (None, 28, 28, 128)       0
#
#  conv2d_108 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_108 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_100 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_109 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_109 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_101 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_110 (Conv2D)         (None, 14, 14, 256)       295168
#
#  batch_normalization_110 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_102 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_111 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_111 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_103 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_112 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_112 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_104 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_113 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_113 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_105 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_114 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_114 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_106 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_115 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_115 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_107 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_116 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_116 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_108 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_117 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_117 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_109 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_118 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_118 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_110 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_119 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_119 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_111 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_120 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_120 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_112 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_121 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_121 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_113 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_122 (Conv2D)         (None, 7, 7, 512)         1180160
#
#  batch_normalization_122 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_114 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_123 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_123 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_115 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_124 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_124 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_116 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_125 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_125 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_117 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_126 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_126 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_118 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_127 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_127 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_119 (Activation)  (None, 7, 7, 512)        0
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 21,138,826
# Trainable params: 21,123,594
# Non-trainable params: 15,232
# _________________________________________________________________

# %% [markdown]
# ### plainnet50

# %%
plain_50 = build_plainnet(input_shape=(224,224,3), is_50=True)
plain_50.summary()
# Out:
# Model: "plainnet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_128 (Conv2D)         (None, 112, 112, 64)      9472
#
#  batch_normalization_128 (Ba  (None, 112, 112, 64)     256
#  tchNormalization)
#
#  activation_120 (Activation)  (None, 112, 112, 64)     0
#
#  max_pooling2d_3 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_129 (Conv2D)         (None, 56, 56, 64)        4160
#
#  batch_normalization_129 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_121 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_130 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_130 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_122 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_131 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_131 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_123 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_132 (Conv2D)         (None, 56, 56, 64)        16448
#
#  batch_normalization_132 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_124 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_133 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_133 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_125 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_134 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_134 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_126 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_135 (Conv2D)         (None, 56, 56, 64)        16448
#
#  batch_normalization_135 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_127 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_136 (Conv2D)         (None, 56, 56, 64)        36928
#
#  batch_normalization_136 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_128 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_137 (Conv2D)         (None, 56, 56, 256)       16640
#
#  batch_normalization_137 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_129 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_138 (Conv2D)         (None, 28, 28, 128)       32896
#
#  batch_normalization_138 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_130 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_139 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_139 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_131 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_140 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_140 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_132 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_141 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_141 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_133 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_142 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_142 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_134 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_143 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_143 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_135 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_144 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_144 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_136 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_145 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_145 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_137 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_146 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_146 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_138 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_147 (Conv2D)         (None, 28, 28, 128)       65664
#
#  batch_normalization_147 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_139 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_148 (Conv2D)         (None, 28, 28, 128)       147584
#
#  batch_normalization_148 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_140 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_149 (Conv2D)         (None, 28, 28, 512)       66048
#
#  batch_normalization_149 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_141 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_150 (Conv2D)         (None, 14, 14, 256)       131328
#
#  batch_normalization_150 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_142 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_151 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_151 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_143 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_152 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_152 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_144 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_153 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_153 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_145 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_154 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_154 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_146 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_155 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_155 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_147 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_156 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_156 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_148 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_157 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_157 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_149 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_158 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_158 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_150 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_159 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_159 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_151 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_160 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_160 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_152 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_161 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_161 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_153 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_162 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_162 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_154 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_163 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_163 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_155 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_164 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_164 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_156 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_165 (Conv2D)         (None, 14, 14, 256)       262400
#
#  batch_normalization_165 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_157 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_166 (Conv2D)         (None, 14, 14, 256)       590080
#
#  batch_normalization_166 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_158 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_167 (Conv2D)         (None, 14, 14, 1024)      263168
#
#  batch_normalization_167 (Ba  (None, 14, 14, 1024)     4096
#  tchNormalization)
#
#  activation_159 (Activation)  (None, 14, 14, 1024)     0
#
#  conv2d_168 (Conv2D)         (None, 7, 7, 512)         524800
#
#  batch_normalization_168 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_160 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_169 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_169 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_161 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_170 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_170 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_162 (Activation)  (None, 7, 7, 2048)       0
#
#  conv2d_171 (Conv2D)         (None, 7, 7, 512)         1049088
#
#  batch_normalization_171 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_163 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_172 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_172 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_164 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_173 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_173 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_165 (Activation)  (None, 7, 7, 2048)       0
#
#  conv2d_174 (Conv2D)         (None, 7, 7, 512)         1049088
#
#  batch_normalization_174 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_166 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_175 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  batch_normalization_175 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_167 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_176 (Conv2D)         (None, 7, 7, 2048)        1050624
#
#  batch_normalization_176 (Ba  (None, 7, 7, 2048)       8192
#  tchNormalization)
#
#  activation_168 (Activation)  (None, 7, 7, 2048)       0
#
#  global_average_pooling2d_3   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 20,820,106
# Trainable params: 20,774,666
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ## 4) ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

# %%
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
# 데이터 개수 확인
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, (224,224))
    image = tf.cast(image, tf.float32) / 255.
    return image, label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    #ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
BATCH_SIZE = 32
EPOCH = 10

# %%
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
resnet_34 = build_resnet(input_shape=(224, 224, 3), 
                         num_classes=1, 
                         is_50=False)

# %%
resnet_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy'],
)

history_resnet_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# 581/581 [==============================] - 113s 145ms/step - loss: 0.6765 - accuracy: 0.6183 - val_loss: 0.8586 - val_accuracy: 0.5032
# Epoch 2/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.6048 - accuracy: 0.6777 - val_loss: 1.6437 - val_accuracy: 0.5152
# Epoch 3/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.5265 - accuracy: 0.7437 - val_loss: 0.5408 - val_accuracy: 0.7294
# Epoch 4/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.4715 - accuracy: 0.7809 - val_loss: 0.8376 - val_accuracy: 0.6002
# Epoch 5/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.4103 - accuracy: 0.8107 - val_loss: 2.0635 - val_accuracy: 0.5784
# Epoch 6/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.3456 - accuracy: 0.8480 - val_loss: 20.5059 - val_accuracy: 0.6107
# Epoch 7/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.2859 - accuracy: 0.8798 - val_loss: 0.8369 - val_accuracy: 0.7829
# Epoch 8/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.2439 - accuracy: 0.8975 - val_loss: 0.9420 - val_accuracy: 0.8373
# Epoch 9/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.2114 - accuracy: 0.9127 - val_loss: 0.5995 - val_accuracy: 0.8691
# Epoch 10/10
# 581/581 [==============================] - 77s 132ms/step - loss: 0.1876 - accuracy: 0.9222 - val_loss: 0.5352 - val_accuracy: 0.8363

# %%
df_resnet_34 = pd.DataFrame({
    'train_loss': history_resnet_34.history['loss'],
    'val_acc': history_resnet_34.history['val_accuracy']
    })
df_resnet_34.to_csv('history_resnet_34.csv', index=False)

# %%
resnet_50 = build_resnet(input_shape=(224, 224, 3), 
                         num_classes=1, 
                         is_50=True)

# %%
resnet_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy'],
)

history_resnet_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# 581/581 [==============================] - 135s 203ms/step - loss: 0.6876 - accuracy: 0.6255 - val_loss: 0.6929 - val_accuracy: 0.5420
# Epoch 2/10
# 581/581 [==============================] - 117s 201ms/step - loss: 0.6000 - accuracy: 0.6835 - val_loss: 3.4093 - val_accuracy: 0.4468
# Epoch 3/10
# 581/581 [==============================] - 117s 202ms/step - loss: 0.5103 - accuracy: 0.7505 - val_loss: 0.9805 - val_accuracy: 0.6429
# Epoch 4/10
# 581/581 [==============================] - 117s 202ms/step - loss: 0.4364 - accuracy: 0.7973 - val_loss: 1.1890 - val_accuracy: 0.5532
# Epoch 5/10
# 581/581 [==============================] - 117s 202ms/step - loss: 0.3771 - accuracy: 0.8336 - val_loss: 1.0713 - val_accuracy: 0.6823
# Epoch 6/10
# 581/581 [==============================] - 117s 202ms/step - loss: 0.3136 - accuracy: 0.8643 - val_loss: 1.0989 - val_accuracy: 0.5768
# Epoch 7/10
# 581/581 [==============================] - 117s 202ms/step - loss: 0.2703 - accuracy: 0.8857 - val_loss: 0.3314 - val_accuracy: 0.8697
# Epoch 8/10
# 581/581 [==============================] - 118s 204ms/step - loss: 0.2359 - accuracy: 0.9016 - val_loss: 0.4546 - val_accuracy: 0.8272
# Epoch 9/10
# 581/581 [==============================] - 118s 203ms/step - loss: 0.2026 - accuracy: 0.9164 - val_loss: 0.3942 - val_accuracy: 0.8690
# Epoch 10/10
# 581/581 [==============================] - 118s 203ms/step - loss: 0.1790 - accuracy: 0.9284 - val_loss: 0.2440 - val_accuracy: 0.9000

# %%
df_resnet_50 = pd.DataFrame({
    'train_loss': history_resnet_50.history['loss'],
    'val_acc': history_resnet_50.history['val_accuracy']
    })
df_resnet_50.to_csv('history_resnet_50.csv', index=False)

# %%
plain_34 = build_plainnet(input_shape=(224, 224, 3), 
                          num_classes=1, 
                          is_50=False)

# %%
plain_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy'],
)

history_plain_34 = plain_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# 581/581 [==============================] - 90s 130ms/step - loss: 0.6972 - accuracy: 0.5198 - val_loss: 1.1780 - val_accuracy: 0.5129
# Epoch 2/10
# 581/581 [==============================] - 75s 129ms/step - loss: 0.6719 - accuracy: 0.5602 - val_loss: 0.6796 - val_accuracy: 0.5123
# Epoch 3/10
# 581/581 [==============================] - 75s 129ms/step - loss: 0.6610 - accuracy: 0.5830 - val_loss: 0.6977 - val_accuracy: 0.5182
# Epoch 4/10
# 581/581 [==============================] - 75s 130ms/step - loss: 0.6539 - accuracy: 0.6043 - val_loss: 5.1541 - val_accuracy: 0.5170
# Epoch 5/10
# 581/581 [==============================] - 75s 129ms/step - loss: 0.6463 - accuracy: 0.6105 - val_loss: 0.8693 - val_accuracy: 0.5481
# Epoch 6/10
# 581/581 [==============================] - 76s 131ms/step - loss: 0.6337 - accuracy: 0.6301 - val_loss: 1.5028 - val_accuracy: 0.5500
# Epoch 7/10
# 581/581 [==============================] - 76s 131ms/step - loss: 0.6153 - accuracy: 0.6580 - val_loss: 0.6617 - val_accuracy: 0.6305
# Epoch 8/10
# 581/581 [==============================] - 76s 131ms/step - loss: 0.5881 - accuracy: 0.6829 - val_loss: 1.3302 - val_accuracy: 0.5866
# Epoch 9/10
# 581/581 [==============================] - 76s 130ms/step - loss: 0.5381 - accuracy: 0.7308 - val_loss: 0.8654 - val_accuracy: 0.6210
# Epoch 10/10
# 581/581 [==============================] - 76s 130ms/step - loss: 0.4846 - accuracy: 0.7688 - val_loss: 0.6920 - val_accuracy: 0.6498

# %%
df_plain_34 = pd.DataFrame({
    'train_loss': history_plain_34.history['loss'],
    'val_acc': history_plain_34.history['val_accuracy']
    })
df_plain_34.to_csv('history_plain_34.csv', index=False)

# %%
plain_50 = build_plainnet(input_shape=(224, 224, 3), 
                          num_classes=1, 
                          is_50=True)

# %%
plain_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy'],
)

history_plain_50 = plain_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# 581/581 [==============================] - 119s 177ms/step - loss: 0.7062 - accuracy: 0.4965 - val_loss: 0.6949 - val_accuracy: 0.4843
# Epoch 2/10
# 581/581 [==============================] - 102s 176ms/step - loss: 0.6903 - accuracy: 0.5296 - val_loss: 0.7247 - val_accuracy: 0.5335
# Epoch 3/10
# 581/581 [==============================] - 102s 176ms/step - loss: 0.6906 - accuracy: 0.5361 - val_loss: 0.6925 - val_accuracy: 0.5024
# Epoch 4/10
# 581/581 [==============================] - 102s 176ms/step - loss: 0.6848 - accuracy: 0.5553 - val_loss: 0.7818 - val_accuracy: 0.4924
# Epoch 5/10
# 581/581 [==============================] - 103s 177ms/step - loss: 0.6729 - accuracy: 0.5906 - val_loss: 0.7073 - val_accuracy: 0.5364
# Epoch 6/10
# 581/581 [==============================] - 103s 178ms/step - loss: 0.6865 - accuracy: 0.5543 - val_loss: 0.7265 - val_accuracy: 0.5183
# Epoch 7/10
# 581/581 [==============================] - 103s 178ms/step - loss: 0.6836 - accuracy: 0.5559 - val_loss: 26.5285 - val_accuracy: 0.5106
# Epoch 8/10
# 581/581 [==============================] - 103s 178ms/step - loss: 0.6951 - accuracy: 0.5207 - val_loss: 0.7001 - val_accuracy: 0.5121
# Epoch 9/10
# 581/581 [==============================] - 104s 179ms/step - loss: 0.6922 - accuracy: 0.5245 - val_loss: 0.6900 - val_accuracy: 0.5316
# Epoch 10/10
# 581/581 [==============================] - 103s 177ms/step - loss: 0.6915 - accuracy: 0.5243 - val_loss: 0.6891 - val_accuracy: 0.5385

# %%
df_plain_50 = pd.DataFrame({
    'train_loss': history_plain_50.history['loss'],
    'val_acc': history_plain_50.history['val_accuracy']
    })
df_plain_50.to_csv('history_plain_50.csv', index=False)

# %%
history_resnet_34 = pd.read_csv('history_resnet_34.csv')
history_resnet_50 = pd.read_csv('history_resnet_50.csv')
history_plain_34 = pd.read_csv('history_plain_34.csv')
history_plain_50 = pd.read_csv('history_plain_50.csv')

# %%
# ResNet-34 vs Plain-34
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_resnet_34['train_loss'], 'r')
plt.plot(history_plain_34['train_loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet-34', 'Plain-34'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(history_resnet_34['val_acc'], 'r')
plt.plot(history_plain_34['val_acc'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet-34', 'Plain-34'], loc='upper left')
plt.show()

# %%
# ResNet-50 vs Plain-50
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_resnet_50['train_loss'], 'r')
plt.plot(history_plain_50['train_loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet-50', 'Plain-50'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(history_resnet_50['val_acc'], 'r')
plt.plot(history_plain_50['val_acc'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet-50', 'Plain-50'], loc='upper left')
plt.show()

# %%
# 전체 비교
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_resnet_34['train_loss'], 'b')
plt.plot(history_resnet_50['train_loss'], 'r')
plt.plot(history_plain_34['train_loss'], 'g')
plt.plot(history_plain_50['train_loss'], 'k')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet-34', 'ResNet-50', 'Plain-34', 'Plain-50'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(history_resnet_34['val_acc'], 'b')
plt.plot(history_resnet_50['val_acc'], 'r')
plt.plot(history_plain_34['val_acc'], 'g')
plt.plot(history_plain_50['val_acc'], 'k')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet-34', 'ResNet-50', 'Plain-34', 'Plain-50'], loc='upper left')
plt.show()

# %%
# validation accuracy 비교표
accuracy = {
    'Plain': [round(history_plain_34['val_acc'].mean(), 4),
              round(history_plain_50['val_acc'].mean(), 4)],
    'ResNet': [round(history_resnet_34['val_acc'].mean(), 4), 
               round(history_resnet_50['val_acc'].mean(), 4)]
}

df_acc = pd.DataFrame(accuracy, index=['34 layers', '50 layers'])
df_acc
# Out:
#             Plain  ResNet
# 34 layers  0.5646  0.6863
# 50 layers  0.5160  0.6910

# %% [markdown]
# - 그래프를 통해 resnet이 plainnet보다 Loss값이 빠르게 낮아지고 Accuracy 또한 빠르게 증가하는 것을 확인할 수 있습니다.
# - validation accuracy 또한 resnet이 plainnet보다 높은 결과를 보여줍니다.
#
# ---
# ## 회고
# going deeper 시간을 통해 이전에 깊게 알아보지 못했던 resnet에 대한 구조를 알게 되었습니다. 논문을 토대로 논문과 비슷한 결과가 나와주었는데 쉽지 않은 것 같습니다. 시간이 오래 걸려 10 EPOCH 밖에 테스트하지 못했는데, 추후 EPOCH를 늘리고 다른 데이터셋에 대해서의 결과도 확인해 보고 싶습니다.
